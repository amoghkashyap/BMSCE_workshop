# %%
#We import libraries for linear algebra, graphs, and evaluation of results
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, roc_auc_score
from scipy.ndimage.filters import uniform_filter1d

# %%
#Keras is a high level neural networks library, based on either tensorflow or theano
from keras.models import Sequential, Model
from keras.layers import Conv1D, MaxPool1D, Dense, Dropout, Flatten, \
BatchNormalization, Input, concatenate, Activation
from keras.optimizers import Adam

# %%
INPUT_LIB = './data/'
raw_data = np.loadtxt(INPUT_LIB + 'exoTrain.csv', skiprows=1, delimiter=',')
x_train = raw_data[:, 1:]
y_train = raw_data[:, 0, np.newaxis] - 1.
raw_data = np.loadtxt(INPUT_LIB + 'exoTest.csv', skiprows=1, delimiter=',')
x_test = raw_data[:, 1:]
y_test = raw_data[:, 0, np.newaxis] - 1.
del raw_data

# %% [markdown]
# ## Scale each observation to zero mean and unit variance.

# %%
x_train = ((x_train - np.mean(x_train, axis=1).reshape(-1,1)) / 
           np.std(x_train, axis=1).reshape(-1,1))
x_test = ((x_test - np.mean(x_test, axis=1).reshape(-1,1)) / 
          np.std(x_test, axis=1).reshape(-1,1))

# %% [markdown]
# This is our only preprocessing step: We add an input corresponding to the running average over 200 time steps. This helps the net ignore high frequency noise and instead look at non-local information. Look at the graphs below to see what it does.

# %%
x_train = np.stack([x_train, uniform_filter1d(x_train, axis=1, size=200)], axis=2)
x_test = np.stack([x_test, uniform_filter1d(x_test, axis=1, size=200)], axis=2)

# %% [markdown]
# ## Train the model

# %% [markdown]
# With the Sequential API for Keras, we only need to add the layers one at a time. Each 1D convolutional layers corresponds to a local filter, and then a pooling layer reduces the data length by approximately a factor 4. At the end, there are two dense layers, just as we would in a typical image classifier. Batch normalization layers speed up convergence.

# %%
model = Sequential()
model.add(Conv1D(filters=8, kernel_size=11, activation='relu', input_shape=x_train.shape[1:]))
model.add(MaxPool1D(strides=4))
model.add(BatchNormalization())
model.add(Conv1D(filters=16, kernel_size=11, activation='relu'))
model.add(MaxPool1D(strides=4))
model.add(BatchNormalization())
model.add(Conv1D(filters=32, kernel_size=11, activation='relu'))
model.add(MaxPool1D(strides=4))
model.add(BatchNormalization())
model.add(Conv1D(filters=64, kernel_size=11, activation='relu'))
model.add(MaxPool1D(strides=4))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 3187, 8)           184
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 797, 8)            0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 797, 8)            32
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 787, 16)           1424
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 197, 16)           0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 197, 16)           64
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 187, 32)           5664
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 47, 32)            0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 47, 32)            128
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 37, 64)            22592
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 9, 64)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                36928
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 71,241
# Trainable params: 71,129
# Non-trainable params: 112
# _________________________________________________________________
# None

# %% [markdown]
# The data here is extremely unbalanced, with only a few positive examples. To correct for this, I use the positive examples a lot more often, so that the net sees 50% of each over each bats. Also, I generate new examples by rotating them randomly in time. This is called augmentation and is similar to when we rotate/shift examples in image classification.

# %%
def batch_generator(x_train, y_train, batch_size=32):
    """
    Gives equal number of positive and negative samples, and rotates them randomly in time
    """
    half_batch = batch_size // 2
    x_batch = np.empty((batch_size, x_train.shape[1], x_train.shape[2]), dtype='float32')
    y_batch = np.empty((batch_size, y_train.shape[1]), dtype='float32')
    
    yes_idx = np.where(y_train[:,0] == 1.)[0]
    non_idx = np.where(y_train[:,0] == 0.)[0]
    
    while True:
        np.random.shuffle(yes_idx)
        np.random.shuffle(non_idx)
    
        x_batch[:half_batch] = x_train[yes_idx[:half_batch]]
        x_batch[half_batch:] = x_train[non_idx[half_batch:batch_size]]
        y_batch[:half_batch] = y_train[yes_idx[:half_batch]]
        y_batch[half_batch:] = y_train[non_idx[half_batch:batch_size]]
    
        for i in range(batch_size):
            sz = np.random.randint(x_batch.shape[1])
            x_batch[i] = np.roll(x_batch[i], sz, axis = 0)
     
        yield x_batch, y_batch

# %% [markdown]
# The hyperparameters here are chosen to finish training within the Kernel, rather than to get optimal results. On a GPU, I might have chosen a smaller learning rate, and perhaps SGD instead of Adam. As it turned out, results were brilliant anyway.

# %%
#Start with a slightly lower learning rate, to ensure convergence
model.compile(optimizer=Adam(1e-5), loss = 'binary_crossentropy', metrics=['accuracy'])
hist = model.fit_generator(batch_generator(x_train, y_train, 32), 
                           validation_data=(x_test, y_test), 
                           verbose=0, epochs=5,
                           steps_per_epoch=x_train.shape[1]//32)

# %%
#Then speed things up a little
model.compile(optimizer=Adam(4e-5), loss = 'binary_crossentropy', metrics=['accuracy'])
hist = model.fit_generator(batch_generator(x_train, y_train, 32), 
                           validation_data=(x_test, y_test), 
                           verbose=2, epochs=40,
                           steps_per_epoch=x_train.shape[1]//32)
# Out:
# Epoch 1/40
#  - 2s - loss: 0.7181 - acc: 0.5401 - val_loss: 0.5156 - val_acc: 0.8860
# Epoch 2/40
#  - 1s - loss: 0.6987 - acc: 0.5590 - val_loss: 0.5323 - val_acc: 0.8649
# Epoch 3/40
#  - 1s - loss: 0.6954 - acc: 0.5606 - val_loss: 0.5120 - val_acc: 0.8877
# Epoch 4/40
#  - 1s - loss: 0.6771 - acc: 0.5859 - val_loss: 0.5162 - val_acc: 0.8789
# Epoch 5/40
#  - 1s - loss: 0.6603 - acc: 0.6158 - val_loss: 0.5251 - val_acc: 0.8702
# Epoch 6/40
#  - 1s - loss: 0.6477 - acc: 0.6272 - val_loss: 0.4982 - val_acc: 0.8860
# Epoch 7/40
#  - 1s - loss: 0.6401 - acc: 0.6304 - val_loss: 0.4922 - val_acc: 0.8737
# Epoch 8/40
#  - 1s - loss: 0.6309 - acc: 0.6509 - val_loss: 0.4881 - val_acc: 0.8860
# Epoch 9/40
#  - 1s - loss: 0.6198 - acc: 0.6686 - val_loss: 0.4818 - val_acc: 0.8912
# Epoch 10/40
#  - 1s - loss: 0.6130 - acc: 0.6676 - val_loss: 0.4675 - val_acc: 0.9035
# Epoch 11/40
#  - 1s - loss: 0.6048 - acc: 0.6853 - val_loss: 0.4669 - val_acc: 0.8947
# Epoch 12/40
#  - 1s - loss: 0.5814 - acc: 0.7102 - val_loss: 0.4491 - val_acc: 0.8930
# Epoch 13/40
#  - 1s - loss: 0.5723 - acc: 0.7055 - val_loss: 0.4438 - val_acc: 0.8825
# Epoch 14/40
#  - 1s - loss: 0.5488 - acc: 0.7143 - val_loss: 0.4296 - val_acc: 0.8912
# Epoch 15/40
#  - 1s - loss: 0.5412 - acc: 0.7408 - val_loss: 0.4033 - val_acc: 0.8982
# Epoch 16/40
#  - 1s - loss: 0.5295 - acc: 0.7371 - val_loss: 0.4155 - val_acc: 0.8789
# Epoch 17/40
#  - 1s - loss: 0.5234 - acc: 0.7434 - val_loss: 0.3948 - val_acc: 0.8842
# Epoch 18/40
#  - 1s - loss: 0.5119 - acc: 0.7585 - val_loss: 0.3926 - val_acc: 0.8754
# Epoch 19/40
#  - 1s - loss: 0.4906 - acc: 0.7623 - val_loss: 0.4051 - val_acc: 0.8544
# Epoch 20/40
#  - 1s - loss: 0.4869 - acc: 0.7696 - val_loss: 0.3878 - val_acc: 0.8544
# Epoch 21/40
#  - 1s - loss: 0.4859 - acc: 0.7683 - val_loss: 0.4075 - val_acc: 0.8333
# Epoch 22/40
#  - 1s - loss: 0.4952 - acc: 0.7614 - val_loss: 0.4078 - val_acc: 0.8298
# Epoch 23/40
#  - 1s - loss: 0.4771 - acc: 0.7746 - val_loss: 0.4113 - val_acc: 0.8263
# Epoch 24/40
#  - 1s - loss: 0.4539 - acc: 0.7800 - val_loss: 0.3785 - val_acc: 0.8368
# Epoch 25/40
#  - 1s - loss: 0.4357 - acc: 0.7945 - val_loss: 0.3741 - val_acc: 0.8351
# Epoch 26/40
#  - 1s - loss: 0.4594 - acc: 0.7857 - val_loss: 0.3502 - val_acc: 0.8439
# Epoch 27/40
#  - 1s - loss: 0.4567 - acc: 0.7825 - val_loss: 0.3989 - val_acc: 0.8211
# Epoch 28/40
#  - 1s - loss: 0.4318 - acc: 0.7989 - val_loss: 0.3465 - val_acc: 0.8368
# Epoch 29/40
#  - 1s - loss: 0.4298 - acc: 0.8040 - val_loss: 0.3479 - val_acc: 0.8386
# Epoch 30/40
#  - 1s - loss: 0.4341 - acc: 0.8033 - val_loss: 0.3185 - val_acc: 0.8474
# Epoch 31/40
#  - 1s - loss: 0.4070 - acc: 0.8188 - val_loss: 0.3596 - val_acc: 0.8333
# Epoch 32/40
#  - 1s - loss: 0.4023 - acc: 0.8134 - val_loss: 0.3358 - val_acc: 0.8368
# Epoch 33/40
#  - 1s - loss: 0.4178 - acc: 0.8116 - val_loss: 0.3110 - val_acc: 0.8491
# Epoch 34/40
#  - 1s - loss: 0.3986 - acc: 0.8141 - val_loss: 0.3057 - val_acc: 0.8474
# Epoch 35/40
#  - 1s - loss: 0.3801 - acc: 0.8229 - val_loss: 0.3295 - val_acc: 0.8351
# Epoch 36/40
#  - 1s - loss: 0.3746 - acc: 0.8362 - val_loss: 0.3030 - val_acc: 0.8474
# Epoch 37/40
#  - 1s - loss: 0.3723 - acc: 0.8343 - val_loss: 0.3128 - val_acc: 0.8439
# Epoch 38/40
#  - 1s - loss: 0.3712 - acc: 0.8359 - val_loss: 0.2938 - val_acc: 0.8526
# Epoch 39/40
#  - 1s - loss: 0.3606 - acc: 0.8336 - val_loss: 0.2760 - val_acc: 0.8561
# Epoch 40/40
#  - 1s - loss: 0.3485 - acc: 0.8479 - val_loss: 0.2832 - val_acc: 0.8544

# %%
plt.plot(hist.history['loss'], color='b')
plt.plot(hist.history['val_loss'], color='r')
plt.show()
plt.plot(hist.history['acc'], color='b')
plt.plot(hist.history['val_acc'], color='r')
plt.show()

# %% [markdown]
# # We then use our trained net to classify the test set.

# %%
non_idx = np.where(y_test[:,0] == 0.)[0]
yes_idx = np.where(y_test[:,0] == 1.)[0]
y_hat = model.predict(x_test)[:,0]

# %% [markdown]
# These graphs show that the five positive examples all get 0.95-1.00 score. Also, almost all negative examples get score close to zero, except a few in the 0.9-1.0 range. This is encouraging.

# %%
plt.plot([y_hat[i] for i in yes_idx], 'bo')
plt.show()
plt.plot([y_hat[i] for i in non_idx], 'ro')
plt.show()

# %% [markdown]
# ## We now choose an optimal cutoff score for classification. Sklearn can help us with this.

# %%
y_true = (y_test[:, 0] + 0.5).astype("int")
fpr, tpr, thresholds = roc_curve(y_true, y_hat)
plt.plot(thresholds, 1.-fpr)
plt.plot(thresholds, tpr)
plt.show()
crossover_index = np.min(np.where(1.-fpr <= tpr))
crossover_cutoff = thresholds[crossover_index]
crossover_specificity = 1.-fpr[crossover_index]
print("Crossover at {0:.2f} with specificity {1:.2f}".format(crossover_cutoff, crossover_specificity))
plt.plot(fpr, tpr)
plt.show()
print("ROC area under curve is {0:.2f}".format(roc_auc_score(y_true, y_hat)))
# Out:
# Crossover at 0.32 with specificity 0.80
# ROC area under curve is 0.88

# %% [markdown]
# Let's take a look at the misclassified data (if any):

# %%
false_positives = np.where(y_hat * (1. - y_test) > 0.5)[0]
for i in non_idx:
    if y_hat[i] > crossover_cutoff:
        print(i)
        plt.plot(x_test[i])
        plt.show()
# Out:
# 7
# 21
# 23
# 25
# 27
# 42
# 46
# 51
# 53
# 54
# 60
# 61
# 65
# 67
# 69
# 77
# 85
# 87
# 89
# 101
# 104
# 109
# 114
# 117
# 120
# 124
# 127
# 136
# 137
# 138
# 139
# 141
# 145
# 148
# 150
# 164
# 169
# 173
# 178
# 183
# 185
# 201
# 206
# 207
# 208
# 209
# 225
# 229
# 233
# 234
# 235
# 242
# 245
# 246
# 247
# 249
# 251
# 258
# 263
# 279
# 280
# 285
# 289
# 292
# 304
# 310
# 313
# 318
# 324
# 332
# 336
# 344
# 347
# 349
# 352
# 360
# 363
# 372
# 386
# 395
# 399
# 400
# 402
# 414
# 415
# 417
# 421
# 432
# 436
# 447
# 460
# 461
# 464
# 465
# 482
# 485
# 486
# 487
# 488
# 493
# 498
# 506
# 508
# 513
# 516
# 520
# 526
# 527
# 540
# 543
# 545
# 549
# 550
# 553
# 564
